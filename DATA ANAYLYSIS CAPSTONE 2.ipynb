# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Preprocessing:
# ● Correct the data in the "height" column by replacing it with random
# numbers between 150 and 180. Ensure data consistency and integrity
# before proceeding with analysis. (1 mark)

# %%
data = pd.read_csv("ABC Company.xlsx - Sheet1.csv")
data.head(10)
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# 5   Amir Johnson  Boston Celtics      90       PF   29  06-Sep     240
# 6  Jordan Mickey  Boston Celtics      55       PF   21  06-Aug     235
# 7   Kelly Olynyk  Boston Celtics      41        C   25     7-0     238
# 8   Terry Rozier  Boston Celtics      12       PG   22  06-Feb     190
# 9   Marcus Smart  Boston Celtics      36       PG   22  06-Apr     220
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
data["Height"] = np.random.randint(150,180 , size = len(data))
data.head(10)
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     174     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     168     235
# 2   John Holland  Boston Celtics      30       SG   27     179     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     160     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     162     231
# 5   Amir Johnson  Boston Celtics      90       PF   29     161     240
# 6  Jordan Mickey  Boston Celtics      55       PF   21     175     235
# 7   Kelly Olynyk  Boston Celtics      41        C   25     172     238
# 8   Terry Rozier  Boston Celtics      12       PG   22     158     190
# 9   Marcus Smart  Boston Celtics      36       PG   22     150     220
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
### NOW SAVE THE FILE INTO A NEW CSV 
data.to_csv("cleaned_data.csv" , index= False)

# %%
cleaned = pd.read_csv("cleaned_data.csv")
cleaned.head(20)
# Out:
#                        Name            Team  Number Position  Age  Height  \
# 0             Avery Bradley  Boston Celtics       0       PG   25     174
# 1               Jae Crowder  Boston Celtics      99       SF   25     168
# 2              John Holland  Boston Celtics      30       SG   27     179
# 3               R.J. Hunter  Boston Celtics      28       SG   22     160
# 4             Jonas Jerebko  Boston Celtics       8       PF   29     162
# 5              Amir Johnson  Boston Celtics      90       PF   29     161
# 6             Jordan Mickey  Boston Celtics      55       PF   21     175
# 7              Kelly Olynyk  Boston Celtics      41        C   25     172
# 8              Terry Rozier  Boston Celtics      12       PG   22     158
# 9              Marcus Smart  Boston Celtics      36       PG   22     150
# 10          Jared Sullinger  Boston Celtics       7        C   24     176
# 11            Isaiah Thomas  Boston Celtics       4       PG   27     158
# ...

# %% [markdown]
# Determine the distribution of employees across each team and calculate
# the percentage split relative to the total number of employees. (2 marks)

# %%
t_count = cleaned['Team'].value_counts()
print(t_count)
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# Milwaukee Bucks           16
# New York Knicks           16
# Boston Celtics            15
# Los Angeles Clippers      15
# Los Angeles Lakers        15
# Phoenix Suns              15
# Sacramento Kings          15
# Brooklyn Nets             15
# Philadelphia 76ers        15
# Toronto Raptors           15
# Golden State Warriors     15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Houston Rockets           15
# San Antonio Spurs         15
# Atlanta Hawks             15
# Dallas Mavericks          15
# Charlotte Hornets         15
# Miami Heat                15
# Denver Nuggets            15
# Washington Wizards        15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
## percentage can be taken by a / total *100

t_count_percentage = (t_count / len(cleaned) ) * 100
print(t_count_percentage.round(2))
# Out:
# Team
# New Orleans Pelicans      4.15
# Memphis Grizzlies         3.93
# Utah Jazz                 3.49
# Milwaukee Bucks           3.49
# New York Knicks           3.49
# Boston Celtics            3.28
# Los Angeles Clippers      3.28
# Los Angeles Lakers        3.28
# Phoenix Suns              3.28
# Sacramento Kings          3.28
# Brooklyn Nets             3.28
# Philadelphia 76ers        3.28
# Toronto Raptors           3.28
# Golden State Warriors     3.28
# Indiana Pacers            3.28
# Detroit Pistons           3.28
# Cleveland Cavaliers       3.28
# Chicago Bulls             3.28
# Houston Rockets           3.28
# San Antonio Spurs         3.28
# Atlanta Hawks             3.28
# Dallas Mavericks          3.28
# Charlotte Hornets         3.28
# Miami Heat                3.28
# Denver Nuggets            3.28
# Washington Wizards        3.28
# Portland Trail Blazers    3.28
# Oklahoma City Thunder     3.28
# Orlando Magic             3.06
# Minnesota Timberwolves    3.06
# ...

# %% [markdown]
# Segregate employees based on their positions within the company

# %%
cleaned.head(3)
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     174     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     168     235
# 2   John Holland  Boston Celtics      30       SG   27     179     205
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
grouped_position = cleaned.groupby('Position')

for position, group in grouped_position:
    print(f"\nPOSITION: {position}")
    # Print only the important columns
    print(group[['Name', 'Team']].to_string(index=False))
# Out:
# POSITION: C
#                Name                   Team
#        Kelly Olynyk         Boston Celtics
#     Jared Sullinger         Boston Celtics
#        Tyler Zeller         Boston Celtics
#         Brook Lopez          Brooklyn Nets
#          Henry Sims          Brooklyn Nets
#         Robin Lopez        New York Knicks
#      Kevin Seraphin        New York Knicks
#         Joel Embiid     Philadelphia 76ers
#       Jahlil Okafor     Philadelphia 76ers
#     Bismack Biyombo        Toronto Raptors
#      Lucas Nogueira        Toronto Raptors
#   Jonas Valanciunas        Toronto Raptors
#        Andrew Bogut  Golden State Warriors
#        Festus Ezeli  Golden State Warriors
#   Marreese Speights  Golden State Warriors
#        Cole Aldrich   Los Angeles Clippers
#      DeAndre Jordan   Los Angeles Clippers
#         Tarik Black     Los Angeles Lakers
#         Roy Hibbert     Los Angeles Lakers
#        Robert Sacre     Los Angeles Lakers
# ...

# %% [markdown]
# Identify the predominant age group among employees. (2 marks)

# %%
cleaned.head(10)

age_count = cleaned['Age'].value_counts()
print(age_count)
print()
predominant_group = age_count.idxmax()
print(f'The dominand age group is {predominant_group}')
print()
group_age = age_count.max()
print(f'The num of people in the age group is {group_age}')
print()
print(f'THE MOST DOMINANT AGE GROUP IN THE FILE IS {predominant_group} and the count of the people in this age group  is {group_age}')
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 30    31
# 28    31
# 29    28
# 22    26
# 31    22
# 21    19
# 20    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 19     2
# 39     2
# Name: count, dtype: int64
#
# The dominand age group is 24
#
# The num of people in the age group is 47
#
# THE MOST DOMINANT AGE GROUP IN THE FILE IS 24 and the count of the people in this age group  is 47

# %% [markdown]
# Discover which team and position have the highest salary expenditure. (2
# marks)

# %%
cleaned.head(10)
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     174     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     168     235
# 2   John Holland  Boston Celtics      30       SG   27     179     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     160     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     162     231
# 5   Amir Johnson  Boston Celtics      90       PF   29     161     240
# 6  Jordan Mickey  Boston Celtics      55       PF   21     175     235
# 7   Kelly Olynyk  Boston Celtics      41        C   25     172     238
# 8   Terry Rozier  Boston Celtics      12       PG   22     158     190
# 9   Marcus Smart  Boston Celtics      36       PG   22     150     220
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
most_paid_team_list= cleaned.groupby("Team")["Salary"].sum().sort_values(ascending=False)
print("THE TEAM EXPENDITURE LIST OF TOP 5 IS  : ")
print(most_paid_team_list.head())
print("----------------------------------------------------------")
print()
most_paid_team = most_paid_team_list.idxmax()
print(f'THE MOST PAID TEAM ON THE LIST IS  : {most_paid_team}')
print("----------------------------------------------------------")
print()
most_paid_position_list =  cleaned.groupby('Position')['Salary'].sum().sort_values(ascending=False)
print("THE TOP 5 PAID POSITION ON THE LIST  :")
print(most_paid_position_list.head())
print("----------------------------------------------------------")
print()
most_paid_position = most_paid_position_list.idxmax()
print(f'THE MOST PAID POSITION ON THE LIST IS :  {most_paid_position}')
print()
# Out:
# THE TEAM EXPENDITURE LIST OF TOP 5 IS  :
# Team
# Cleveland Cavaliers      106988689.0
# Los Angeles Clippers      94854640.0
# Oklahoma City Thunder     93765298.0
# Golden State Warriors     88868997.0
# Chicago Bulls             86783378.0
# Name: Salary, dtype: float64
# ----------------------------------------------------------
#
# THE MOST PAID TEAM ON THE LIST IS  : Cleveland Cavaliers
# ----------------------------------------------------------
#
# THE TOP 5 PAID POSITION ON THE LIST  :
# Position
# C     466377332.0
# PG    446848971.0
# PF    442560850.0
# SF    408020976.0
# SG    396976258.0
# Name: Salary, dtype: float64
# ----------------------------------------------------------
#
# THE MOST PAID POSITION ON THE LIST IS :  C

# %% [markdown]
# Investigate if there's any correlation between age and salary, and
# represent it visually. (2 marks)

# %%
corr = cleaned['Age'].corr(cleaned['Salary'])
print(f'THE CORELATION BTW THE AGE AND SALARY IS {corr:.2f}')
# Out:
# THE CORELATION BTW THE AGE AND SALARY IS 0.21

# %%
plt.figure(figsize=(10, 5))
plt.scatter(cleaned['Age'], cleaned['Salary'], edgecolors='w', linewidth=10)
plt.title('Age vs Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.grid(True)
plt.show()

# %% [markdown]
# THE GRAPH PLOT FOR EACH :

# %% [markdown]
# A :

# %%
plt.figure(figsize=(20,6))
t_count.plot(kind='bar', color='skyblue')
plt.title("Number of Employees per Team")
plt.xlabel("Team")
plt.ylabel("Number of Employees")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# B : THE PERCENTAGE PLOT

# %%
plt.figure(figsize=(8,8))
t_count_percentage.plot(kind='pie', autopct='%1.1f%%')

plt.title("Percentage of Employees per Team")
plt.tight_layout()
plt.show()

# %% [markdown]
# C :● Identify the predominant age group among employees. (2 marks)

# %%
plt.figure(figsize=(8,5))
age_count.plot(kind='bar', color='orange')
plt.title("Top 5 Most Common Ages")
plt.xlabel("Age")
plt.ylabel("Number of Employees")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
